# %%
happy_music=[
    "happy-day",
    "Chaleya",
    "embrace",
    "O mahi",
    "guitar-electro-sport-trailer",
    "inside-you",
    "simple-piano-melody",
    "summer-adventures",
    "the-cradle-of-your-soul",
]



sad_music=[
    "dramatic-atmosphere-with-piano-and-violin",
    
    "emotional-piano",
    "Kesariya",
    "middle-east",
    "sub-arban",
    "o Bedardeya",
    "tu hai kaha",
    "Satranga",
    "kun faya kun",
    "Ranjha"
    
]
arjit_singh_music=[
    "o Bedardeya",
    "Ranjha"
]
lata_mangeshkar_music=[
    "Kesariya",
    "middle-east",
    "sub-arban",
    "o Bedardeya",
    "tu hai kaha"
]
kumar_sanu_music=[ 
    "Chaleya",
    "embrace",
    "O mahi",
    "guitar-electro-sport-trailer",
    "inside-you"
    
]

user_mood=input('enter your mood (happy/sad):')
if user_mood=="happy":
 print(happy_music)
elif user_mood=="sad":
 print(sad_music)
else:
 print("worng input")

   
singer=input('choose your favourite singer(arjit_singh/lata_mangeshkar/kumar_sanu):')

if singer=="arjit_singh":
 print(arjit_singh_music)
elif singer=="lata_mangeshkar":
 print(lata_mangeshkar_music)
elif singer=="kumar_sanu":
   print(kumar_sanu_music)
else:
   print("no singar found")
like=input('do you like this music')
if like=="yes":
    if singer=="arjit_singh":
      print(arjit_singh_music)
    elif singer=="lata_mangeshkar":
      print(lata_mangeshkar_music)
    else:
      print(kumar_sanu_music)
else:
    print("then choose year")
year_2021=[
    "padmavt",
    "ranjna",
    "jannat",
    "tip tip",
    "isa kadar",
    "meri zindagi",
    "chaka chak"
]
year_2022=[
    "satranga",
    "bevfa tera masum chehra",
    "hireeye",
    "tere vaste",
    "raabta",
    "tanha",
    "le aaun ga"
]
year_2023=[
    "phele bhi main",
    "oh mahi",
    "bhag milkha bhag",
    "chaleya",
    "kya loge tum",
    "sanak",
    "tere zakir",
    "mann meri jaan"
]

    

year=input('choose your favourite year(year_2021/year_2022/year_2023):')
if year=="year_2021":
 print(year_2021)
elif year=="year_2022":
 print(year_2022)
elif year=="year_2023":
 print(year_2023)
else:
 print("song is not foud")
print("you want choose another language songs telgu_songs,tamil_songs,punjabi_songs,marathi_songs,kannad_songs")

telgu_songs=["ramuloo ramulaa",

"buttabomma",

"yenti yenti",

"srivalli", "kalavathi",

"aradhya",

"arebic kuthu",

"na roja nuvve",

"seeti maar",

"ala vaikunthapurramuloo"]



tamil_songs=["thee thalapathy",

"ordinary person",

"thuli thuli",

"hukum",

"kadhal aasai",

"Lokiverse",

"en jeevan",

"eena meena teeka",

"chella kutti",

"thaimai",

]


panjabi_songs=["cheques",
               "still collin",
               "one love",
               "no love",
               "extuses",
               "summer high",
               "Brown Munde", 
               "Sakhlyaan",
               "daku"]

marathi_songs=["baharala ha madbumas nava", "gau nako kisna",

"Jay jay maharashtra maza",

"antabai gondhalala ye","mauli mauli"

]
kannad_songs=["nenna tanaka",


"ninnidale",

"ninna gungalli",

"hesaru poorthi",

"nana mele nanageego",

"kesartya rangu","yaaro kannalli",

"singara sirtye"]
language = input("Enter a language: ")
def print_list(list):
    for item in list:
        print(item,end='   ')

if language == "telgu_songs":
    print_list(telgu_songs)
elif language == "tamil_songs":
    print_list(tamil_songs)
elif language == "panjabi_songs":
    print_list(panjabi_songs)
elif language == "marathi_songs":
    print_list(marathi_songs)
elif language == "kannad_songs":
    print_list(kannad_songs)  




    
telgusong={"ramuloo ramulaa":"movie-ala vaikutunthapurramuloo singer- anurag kulkarni,mangali",
             "buttabomma":"movie-ala vaikutunthapurramuloo singer- arman malik",
             "yenti yenti":"movie-geetha govindam singer- chinmayi",
             "srivalli":"movie-pushpa singer- sid sriram",
             "kalavathi":"movie-kalavathi singer- thaman s",
             "aradhya":"movie-kushi singer-sid siram ",
             "arebic kuthu":"movie-beast singer-anirudh ravichandar ",
             "na roja nuvve":"movie-kushi  singer-shiva nirvana ",
             "seeti maar":"movie-DJ singer-jaspreet jasz, rita ",
             "ala vaikunthapurramuloo":"movie-ala vaikunthapurramuloo singar-arman malik ",
           }



tamilsongs={"thee thalapathy":"movie-varsiu singer-anirudh ravichandar",
             "ordinary person":"movie-leo singer-anirudh ravichandar",
             "thuli thuli":"movie-thuli thuli singer-haricharan",
             "hukum":"movie-jailer singer-anirudha ravichander",
             "kadhal aasai":"movie-anjaan singer-soorj shankar",
             "Lokiverse":"movie-leo singer-anirudh ravichandar",
             "en jeevan":"movie-theri singer-hariharan",
             "eena meena teeka":"movie-theri singer-g.v prakash kumar",
             "chella kutti":"movie-theri singer-g.v prakash kumar",
             "thaimai":"movie-theri singer-bombay jayashri",

            }
panjabisongs={"cheques":"singer-shubh",
               "still collin":"singer-shubh",
               "one love":"singer-shubh",
               "no love":"singer-shubh",
               "extuses":"singer-A P dhilloin",
               "summer high":"singer-shubh",
               "Brown Munde":"singer-A P dhilloin",
               "Sakhlyaan":"singer-shubh",
               "daku":"singar-shubh"
              }

marathisongs={"baharala ha madbumas nava":"movie-maharashtra shaheer singer-ajay-atul", 
               "gau nako kisna":"movie-maharashtra shaheer singer-ajay-atul",
               "Jay jay maharashtra maza":" movie-maharashtra shaheer singer-ajay-atul",
               "ambabai gondhalala ye":"movie-maharashtra shaheer singar-ajay atul",
               "mauli mauli":"movie-lai bhari singar-ajay atul",
               

              }
kannadsongs={"nenna tanaka":"movie-trivikrama singer-sanjith hegade",
              "ninnidale":"movie-ninnidale singer-sonu nigam",
              "kesartya rangu":"movie-brahmastra singer-ranbir",
              "yaaro kannalli":"movie-orata singer-rajesh krishana",
              "singara sirtye":"movie-kantara singer-vijay prakash",
              }
if language == "telgu_songs":
    print(telgusongs)
elif language == "tamil_songs":
    print(tamilsongs)
elif language == "panjabi_songs":
    print(panjabisongs)
elif language == "marathi_songs":
    print(marathisongs)
elif language == "kannad_songs":
    print(kannadsongs)
print("english songs")
english=input('you want to listein english song(yes/no):')

import pandas as pd


music_data = {
    'Track Name': ['Shape of You', 'Blinding Lights', 'Old Town Road', 'Dance Monkey', 'Uptown Funk',
                   'Despacito', 'Someone You Loved', 'Closer', 'Perfect', 'Rockstar'],
    'Artist': ['Ed Sheeran', 'The Weeknd', 'Lil Nas X ft. Billy Ray Cyrus', 'Tones and I', 'Mark Ronson ft. Bruno Mars',
               'Luis Fonsi ft. Daddy Yankee', 'Lewis Capaldi', 'The Chainsmokers ft. Halsey', 'Ed Sheeran', 'Post Malone ft. 21 Savage'],
    'Genre': ['Pop', 'Pop', 'Country', 'Pop', 'Funk', 'Reggaeton', 'Pop', 'EDM', 'Pop', 'Hip-hop'],
    'Duration (minutes)': [4.23, 3.22, 1.75, 3.29, 4.31, 3.48, 3.02, 4.05, 4.23, 3.38]
}


df = pd.DataFrame(music_data)

if(english=="yes"):
    print(df)
else:
    print(" ")
    
feedback=input("enter your feedback(exelent/good/bad)")
print(feedback)
print("THANK YOU")
# Out:
# enter your mood (happy/sad): happy
# ['happy-day', 'Chaleya', 'embrace', 'O mahi', 'guitar-electro-sport-trailer', 'inside-you', 'simple-piano-melody', 'summer-adventures', 'the-cradle-of-your-soul']
# choose your favourite singer(arjit_singh/lata_mangeshkar/kumar_sanu): arjit_singh
# ['o Bedardeya', 'Ranjha']
# do you like this music yes
# ['o Bedardeya', 'Ranjha']
# choose your favourite year(year_2021/year_2022/year_2023): year_2021
# ['padmavt', 'ranjna', 'jannat', 'tip tip', 'isa kadar', 'meri zindagi', 'chaka chak']
# you want choose another language songs telgu_songs,tamil_songs,punjabi_songs,marathi_songs,kannad_songs
# Enter a language:  marathi_songs
# ...
